# %% [markdown]
# Ans 1)  *       - Mathematical Operator
#         'hello' - string
#         -87.8   - integer(float)
#         -       - Mathematical Operator
#          /      - Mathematical Operator
#          +      - Mathematical Operator
#          6      - integer
#
# Ans 2)  Variable is used to assign any information temporary , data or value, While string is a type of data which can be assign under any varibale specified with inverted comma.
#
# Ex- X=" Hello World"
#
# x is the varibale
# "Hello World" is string data type assign under X.
#
# Ans 3) Broadly Three Different Data types are-
#
# 1) Number(integer, Float, Complex no.)
# 2) Sequence (String, List, Tuple)
# 3) Mapping (Dictionary)
#
#
# a) integer - It represents the whole no. without any fractional part. it can be positive or negative, irrespective to  size.
# Ex - -84, 88, 5
#
# b) Float - It represents the number with fractional part,it can be positive or negative, irrespective to  size.
# Ex - -84.0, 885.215
#
# c) Complex No. - It is pair of real and imgainary no, Imaginary part is denoted with "j".
# EX - 2+5j
#
# d) String - String is sequence of charater that can be letters, numbers, special symbole or combination of above all enclosed within inverted comma.
#  Ex - 'hello', "shashank454", "4684".
#
#
#  Ans 4) It is Combination of values and  operators. it generates a single value which by itself is an expression.
#
#  EX - 5+2*4 =13
#
#  5+2*4 is expression, in which 5,2 and 4 are values and "+" and "*" are operators and 13 is result of expression.
#
# Ans 5) Expression is set of values and operators, It always evaluate to value while Statement is logical action or instruction which is executed while running a program.
#
# Types of statement is Empty, simple and compound.
#
# Ans 6) 23, Integer type data.
#
# Ans 7)  a) 'spamspamspam'
#         b) 'spamspamspam'
#
# Ans 8) Variable name should not
#        a) start with any number,
#        b) cantain any space,
#        c) contain nay special symbol,
#        d) contain any keyword.
#
# Ans 9) int(), float(), str().
#
# Ans 10) This expression cause an error because in python we cant concatenate string and integer.
#
# We can fix it by changing the integer into string.
# 'I have eaten' + '99' + 'burritos.'
